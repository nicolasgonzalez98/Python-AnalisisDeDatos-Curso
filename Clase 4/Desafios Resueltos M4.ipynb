# %% [markdown]
# # Desafios - Módulo 4 - Resueltos

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# - Ejercicio 1
#     - Crear series a partir de listas y a partir de arrays
#     - Crear dataframes a partir de listas anidadas, y de arrays anidados
#     - Crear dataframes especificando etiquetas para las columnas
#     - Cargar el dataframe del titanic, y visualizar la información basica del mismo

# %%
pd.Series([10,2,5])
# Out:
# 0    10
# 1     2
# 2     5
# dtype: int64

# %%
vector = np.array([5,4,3])

# %%
pd.Series(vector)
# Out:
# 0    5
# 1    4
# 2    3
# dtype: int32

# %%
mLista = [[1,2],[3,4]]
pd.DataFrame(mLista)
# Out:
#    0  1
# 0  1  2
# 1  3  4

# %%
mArray = np.array(mLista)
pd.DataFrame(mArray)
# Out:
#    0  1
# 0  1  2
# 1  3  4

# %%
pd.DataFrame(mArray,columns={"Lunes","Martes"})
# Out:
#    Lunes  Martes
# 0      1       2
# 1      3       4

# %%
tabla = pd.read_csv(r"C:\Users\Distancia\Desktop\analisis de datos\MODULO 4\Diapositivas\titanic.csv")
tabla
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
tabla.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# - Ejercicio 2
#     - De titanic.csv , ya cargado como dataframe:
#         - Seleccionar las columnas “Survived”, “Pclass”, “Age” y “Sex”.
#         - Seleccionar las filas 200 a 400 de las columnas “Name” y “Age”.
#         - Cambiar el nombre de la columna “PassengerId” por “ID”.
#         - Seleccionar los datos de todas las mujeres de primera clase.
#         - Seleccionar los datos de los varones menores de edad de segunda clase.

# %%
tabla[["Survived","Pclass","Age","Sex"]]
# Out:
#      Survived  Pclass   Age     Sex
# 0           0       3  22.0    male
# 1           1       1  38.0  female
# 2           1       3  26.0  female
# 3           1       1  35.0  female
# 4           0       3  35.0    male
# ..        ...     ...   ...     ...
# 886         0       2  27.0    male
# 887         1       1  19.0  female
# 888         0       3   NaN  female
# 889         1       1  26.0    male
# 890         0       3  32.0    male
#
# [891 rows x 4 columns]

# %%
tabla[["Name","Age"]].iloc[200:400]
# Out:
#                                  Name   Age
# 200    Vande Walle, Mr. Nestor Cyriel  28.0
# 201               Sage, Mr. Frederick   NaN
# 202        Johanson, Mr. Jakob Alfred  34.0
# 203              Youseff, Mr. Gerious  45.5
# 204          Cohen, Mr. Gurshon "Gus"  18.0
# ..                                ...   ...
# 395               Johansson, Mr. Erik  22.0
# 396               Olsson, Miss. Elina  31.0
# 397           McKane, Mr. Peter David  46.0
# 398                  Pain, Dr. Alfred  23.0
# 399  Trout, Mrs. William H (Jessie L)  28.0
#
# [200 rows x 2 columns]

# %%
tabla.rename(columns={'PassengerId': "ID"})
# Out:
#       ID  Survived  Pclass                                               Name  \
# 0      1         0       3                            Braund, Mr. Owen Harris
# 1      2         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2      3         1       3                             Heikkinen, Miss. Laina
# 3      4         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4      5         0       3                           Allen, Mr. William Henry
# ..   ...       ...     ...                                                ...
# 886  887         0       2                              Montvila, Rev. Juozas
# 887  888         1       1                       Graham, Miss. Margaret Edith
# 888  889         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889  890         1       1                              Behr, Mr. Karl Howell
# 890  891         0       3                                Dooley, Mr. Patrick
#
# ...

# %%
tabla[(tabla["Sex"]=="female") & (tabla["Pclass"]==1)]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 11            12         1       1
# 31            32         1       1
# 52            53         1       1
# ..           ...       ...     ...
# 856          857         1       1
# 862          863         1       1
# 871          872         1       1
# 879          880         1       1
# 887          888         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 31      Spencer, Mrs. William Augustus (Marie Eugenie)  female   NaN      1
# 52            Harper, Mrs. Henry Sleeper (Myna Haxtun)  female  49.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
tabla[(tabla["Sex"]=="male")&(tabla["Age"]<18)]
# Out:
#      PassengerId  Survived  Pclass  \
# 7              8         0       3
# 16            17         0       3
# 50            51         0       3
# 59            60         0       3
# 63            64         0       3
# 78            79         1       2
# 86            87         0       3
# 125          126         1       3
# 138          139         0       3
# 163          164         0       3
# 164          165         0       3
# 165          166         1       3
# 171          172         0       3
# 182          183         0       3
# 183          184         1       2
# 193          194         1       2
# 220          221         1       3
# 261          262         1       3
# 266          267         0       3
# 278          279         0       3
# 282          283         0       3
# 305          306         1       1
# 333          334         0       3
# 340          341         1       2
# 348          349         1       3
# ...

# %% [markdown]
# - Ejercicio 3
#     - Del titanic.csv ya cargado como dataframe:
#         - Encontrar el promedio de edad de hombres y de las  mujeres.
#         - Encontrar la cantidad de sobrevivientes de hombres y las mujeres.

# %%
tabla[tabla["Sex"]=="male"]["Age"].mean()
# Out:
# 30.72664459161148

# %%
tabla[tabla["Sex"]=="female"]["Age"].mean()
# Out:
# 27.915708812260537

# %%
len(tabla[(tabla["Sex"]=="male") & (tabla["Survived"]==1)])
# Out:
# 109

# %%
len(tabla[(tabla["Sex"]=="female") & (tabla["Survived"]==1)])
# Out:
# 233
